# %% [markdown]
# ## Task 2: Data Cleaning & Missing Value Handling

# %%
import pandas as pd #for data manipulation
import numpy as np #for numerical operations
import matplotlib.pyplot as plt #for plotting the missing values

# %%
df=pd.read_csv('dataset/House_prices.csv') #loading the dataset
